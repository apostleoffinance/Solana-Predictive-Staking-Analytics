# %%
from helius import NFTAPI, NameAPI, BalancesAPI, WebhooksAPI, TransactionsAPI
from dotenv import load_dotenv
from pathlib import Path
import requests
import pandas as pd
import numpy as np
import os
import time
import json
import joblib

# %%
pd.set_option('display.max_colwidth', None)  
pd.set_option('display.max_columns', None)   
pd.set_option('display.width', 200)    
pd.set_option('display.float_format', '{:.8f}'.format)

# %%
df_validators = joblib.load('df_validators.joblib')

df_expanded = joblib.load('df_expanded.joblib')

df_cleaned = joblib.load('df_cleaned.joblib')

df_tps = joblib.load('df_tps.joblib')

df_supply = joblib.load('df_supply.joblib')

df_fees = joblib.load('df_fees.joblib')

df_inflation = joblib.load('df_inflation.joblib')

# %%
df_validators #.head()
# Out:
#       network                                       account                                  name  keybase_id                                 www_url  \
# 0     mainnet  4VrjyXQT61WFSjuG3ehgqZUK1jqvYqB46veQbXLotq3n                 Vault X | 0% fee +MEV        rxtx                  https://stake.solfi.uk
# 1     mainnet  DP9iBgK9c7tJYb83KhxQMFNc1LXYu7nE7EhWpEzQnjmg                                  Sec3              https://www.sec3.dev/solana-validators
# 2     mainnet  7y5VhV4fkz6r4zUmH2UiwPjLwXzPL1PcV28or5NWkWRL  Haus – Guaranteed Best APY & No Fees                           https://www.staking.haus/
# 3     mainnet  AAHSdsnRREfdQNzDGRxai8CLXh9EPCoRdwULPqBYd9fb                             StakeArmy   stakearmy                   https://stakearmy.com
# 4     mainnet   xLabscif2DLnYg39rQThqi7A9E45L9qiysRZhmZ1ARE                                 xLabs                                   https://xlabs.xyz
# ...       ...                                           ...                                   ...         ...                                     ...
# 1215  mainnet  7QQGNm3ptwinipDCyaCF7jY5katgmFUu1ieP2f7nwLpE                                  None        None                                    None
# 1216  mainnet  HNcSu8SVg4fuRyM3XV255totbTe6NPGhPSApzxn4V5Jx                                  None        None                                    None
# 1217  mainnet   b8ThsbsARWyjqWrBdU9JNFhXg8ZAjDaJtaqXXzy1sRS             MARGUS.ONE 💎 0% fee +MEV!  margus_one                      https://margus.one
# 1218  mainnet  D7a59Yada8zeBwngcP8aikfSkrGVWWDpSWuW11HZqsDC                                  None        None                                    None
# 1219  mainnet  6xUK9Nbonr4eoJNtHGoUEMmYKoPz5mipKzyDBv6deX4d                            LuSOL +MEV                           https://lusol.netlify.app
#
#                                                                                                                                                                                                                                                               details  \
# 0                                                                                                                                                                                                                                          Safety, reliability, speed
# 1                                                                                                                                                  Sec3 is a security and research firm providing bespoke audits and cutting edge security software to Web3 projects.
# 2             Haus is a Solana-focused validator with 0% fees. We guarantee the highest returns by matching the highest APY validator on the network (even if it’s not us), and we give large stakers an extra 10% native APY boost. Contact us at info@staking.haus.
# 3                                                                                                                                                                                                                                                         High Uptime
# 4                                                                                                                                                                                        Core infrastructure and open-source contributions for the internet of value.
# ...                                                                                                                                                                                                                                                               ...
# 1215                                                                                                                                                                                                                                                             None
# 1216                                                                                                                                                                                                                                                             None
# 1217  Experience reliable and profitable staking with MARGUS.ONE! Our team of experts ensures 24/7 monitoring, high uptime and stable software for maximum security. With zero commission fees and the Jito-client on our node, you'll earn extra MEV rewards. NO FEE
# 1217   29066-DE-Frankfurt am Main            29066.00000000  50.1169     8.6837                                          None  CzmqDuqEpfnkptuLAcikmJrhCnhFXo8aUBj6Rto1SPAc 148925.00000000
# 1218               18450-US-Ogden            18450.00000000  41.2627  -111.9837  216.200.163.234.IDIA-367305-ZYO.zip.zayo.com  5fdEXhCBKC7FRRsH64asZCSiwgNXRozxmzb1cFzfrtWM 149119.00000000
# 1219            42831-GB-Coventry            42831.00000000   52.382    -1.5874                                          None  8vyuJTHSDkx7k1zymea4TMsgvixf3rCYBXHPDQajePkE 149309.00000000
#
#             epoch                                                                                                url  skipped_slots skipped_slot_percent  ping_time
# 0    787.00000000  https://www.validators.app/api/v1/validators/mainnet/4VrjyXQT61WFSjuG3ehgqZUK1jqvYqB46veQbXLotq3n            NaN                  NaN        NaN
# 1    787.00000000  https://www.validators.app/api/v1/validators/mainnet/DP9iBgK9c7tJYb83KhxQMFNc1LXYu7nE7EhWpEzQnjmg     0.00000000                  0.0        NaN
# 2    787.00000000  https://www.validators.app/api/v1/validators/mainnet/7y5VhV4fkz6r4zUmH2UiwPjLwXzPL1PcV28or5NWkWRL     0.00000000                  0.0        NaN
# 3    787.00000000  https://www.validators.app/api/v1/validators/mainnet/AAHSdsnRREfdQNzDGRxai8CLXh9EPCoRdwULPqBYd9fb     0.00000000                  0.0        NaN
# 4    787.00000000   https://www.validators.app/api/v1/validators/mainnet/xLabscif2DLnYg39rQThqi7A9E45L9qiysRZhmZ1ARE            NaN                  NaN        NaN
# ...           ...                                                                                                ...            ...                  ...        ...
# 1215 787.00000000  https://www.validators.app/api/v1/validators/mainnet/7QQGNm3ptwinipDCyaCF7jY5katgmFUu1ieP2f7nwLpE     0.00000000                  0.0        NaN
# 1216 787.00000000  https://www.validators.app/api/v1/validators/mainnet/HNcSu8SVg4fuRyM3XV255totbTe6NPGhPSApzxn4V5Jx     0.00000000                  0.0        NaN
# 1217 787.00000000   https://www.validators.app/api/v1/validators/mainnet/b8ThsbsARWyjqWrBdU9JNFhXg8ZAjDaJtaqXXzy1sRS            NaN                  NaN        NaN
# 1218 787.00000000  https://www.validators.app/api/v1/validators/mainnet/D7a59Yada8zeBwngcP8aikfSkrGVWWDpSWuW11HZqsDC            NaN                  NaN        NaN
# 1219 787.00000000  https://www.validators.app/api/v1/validators/mainnet/6xUK9Nbonr4eoJNtHGoUEMmYKoPz5mipKzyDBv6deX4d     0.00000000                  0.0        NaN
#
# [1220 rows x 45 columns]

# %%
df_validators.columns.to_list()
# Out:
# ['network',
#  'account',
#  'name',
#  'keybase_id',
#  'www_url',
#  'details',
#  'avatar_url',
#  'created_at',
#  'updated_at',
#  'admin_warning',
#  'jito',
#  'jito_commission',
#  'stake_pools_list',
#  'is_active',
#  'avatar_file_url',
#  'active_stake',
#  'authorized_withdrawer_score',
#  'commission',
#  'data_center_concentration_score',
#  'delinquent',
#  'published_information_score',
#  'root_distance_score',
#  'security_report_score',
#  'skipped_slot_score',
#  'skipped_after_score',
#  'software_version',
#  'software_version_score',
#  'stake_concentration_score',
#  'consensus_mods_score',
#  'vote_latency_score',
#  'total_score',
#  'vote_distance_score',
#  'ip',
#  'data_center_key',
#  'autonomous_system_number',
#  'latitude',
#  'longitude',
#  'data_center_host',
#  'vote_account',
#  'epoch_credits',
#  'epoch',
#  'url',
#  'skipped_slots',
#  'skipped_slot_percent',
#  'ping_time']

# %%
df_expanded.head()
# Out:
#                             timestamp                                    nodePubkey  commission  activatedStake   lastVote   rootSlot  epochVoteAccount  epoch    credits  previous_credits  \
# 4813 2025-05-14 16:11:29.984106+00:00  138KHwTqKNWGLoo8fK5i8UxYtwoC5tC8o7M9rY1CDEjT           0  29324645372960  339993667  339993636              True    783  670375331         663485837
# 4814 2025-05-14 16:11:29.984106+00:00  138KHwTqKNWGLoo8fK5i8UxYtwoC5tC8o7M9rY1CDEjT           0  29324645372960  339993667  339993636              True    784  677274232         670375331
# 4815 2025-05-14 16:11:29.984106+00:00  138KHwTqKNWGLoo8fK5i8UxYtwoC5tC8o7M9rY1CDEjT           0  29324645372960  339993667  339993636              True    785  684174907         677274232
# 4816 2025-05-14 16:11:29.984106+00:00  138KHwTqKNWGLoo8fK5i8UxYtwoC5tC8o7M9rY1CDEjT           0  29324645372960  339993667  339993636              True    786  691053198         684174907
# 4817 2025-05-14 16:11:29.984106+00:00  138KHwTqKNWGLoo8fK5i8UxYtwoC5tC8o7M9rY1CDEjT           0  29324645372960  339993667  339993636              True    787  691207384         691053198
#
#       credits_earned                                    votePubkey
# 4813         6889494  ASfKFAKz6fH4eip1jdLGt5Ym954kU9KYnwq2Csn9ogSz
# 4814         6898901  ASfKFAKz6fH4eip1jdLGt5Ym954kU9KYnwq2Csn9ogSz
# 4815         6900675  ASfKFAKz6fH4eip1jdLGt5Ym954kU9KYnwq2Csn9ogSz
# 4816         6878291  ASfKFAKz6fH4eip1jdLGt5Ym954kU9KYnwq2Csn9ogSz
# 4817          154186  ASfKFAKz6fH4eip1jdLGt5Ym954kU9KYnwq2Csn9ogSz

# %%
df_expanded['vote_account'] = df_expanded['votePubkey']

# %%
# df_expanded.columns.to_list()

# %%
df_merge = df_validators.merge(df_expanded, how = 'left', on = ['vote_account', 'epoch'] )

# %%
df_merge["active_stake_SOL"] = df_merge["active_stake"] / 1e9

# %%
df_merge.head()
# Out:
#    network                                       account                                  name keybase_id                                 www_url  \
# 0  mainnet  4VrjyXQT61WFSjuG3ehgqZUK1jqvYqB46veQbXLotq3n                 Vault X | 0% fee +MEV       rxtx                  https://stake.solfi.uk
# 1  mainnet  DP9iBgK9c7tJYb83KhxQMFNc1LXYu7nE7EhWpEzQnjmg                                  Sec3             https://www.sec3.dev/solana-validators
# 2  mainnet  7y5VhV4fkz6r4zUmH2UiwPjLwXzPL1PcV28or5NWkWRL  Haus – Guaranteed Best APY & No Fees                          https://www.staking.haus/
# 3  mainnet  AAHSdsnRREfdQNzDGRxai8CLXh9EPCoRdwULPqBYd9fb                             StakeArmy  stakearmy                   https://stakearmy.com
# 4  mainnet   xLabscif2DLnYg39rQThqi7A9E45L9qiysRZhmZ1ARE                                 xLabs                                  https://xlabs.xyz
#
#                                                                                                                                                                                                                                                    details  \
# 0                                                                                                                                                                                                                               Safety, reliability, speed
# 1                                                                                                                                       Sec3 is a security and research firm providing bespoke audits and cutting edge security software to Web3 projects.
# 2  Haus is a Solana-focused validator with 0% fees. We guarantee the highest returns by matching the highest APY validator on the network (even if it’s not us), and we give large stakers an extra 10% native APY boost. Contact us at info@staking.haus.
# 3                                                                                                                                                                                                                                              High Uptime
# 4                                                                                                                                                                             Core infrastructure and open-source contributions for the internet of value.
#
#                                                                                         avatar_url               created_at               updated_at admin_warning  jito  jito_commission  \
# 0  https://s3.amazonaws.com/keybase_processed_uploads/c00270ec4b198ab0aa96b654ea7cd605_360_360.jpg  2022-04-24 23:00:09 UTC  2025-02-13 03:40:05 UTC          None  True       0.00000000
# 1                                                         https://pro.sec3.dev/sec3_logo_solid.png  2024-04-23 12:53:25 UTC  2025-04-24 03:40:06 UTC          None  True     800.00000000
# 2                                                            https://www.staking.haus/hauslogo.png  2021-09-30 04:24:13 UTC  2025-05-09 03:40:05 UTC          None  True       0.00000000
# 3  https://s3.amazonaws.com/keybase_processed_uploads/f0dba3e5b88045f95b11db2ebc38ab05_360_360.jpg  2022-03-22 14:19:12 UTC  2024-11-27 03:40:05 UTC          None  True    1000.00000000
# 4                                                                 https://xlabs.xyz/xlabs-icon.png  2024-10-30 15:08:04 UTC  2025-05-09 03:40:05 UTC          None  True    1000.00000000
#
#                stake_pools_list  is_active                                                                   avatar_file_url      active_stake  authorized_withdrawer_score  commission_x  \
# 0           [BlazeStake, Jpool]       True  https://prod-validators.nyc3.digitaloceanspaces.com/xclfhh3xmp20ku2py7j4ndjhmiiz   129778594625380                            0             0
# 1                        [Aero]       True  https://prod-validators.nyc3.digitaloceanspaces.com/zia1i71u0ozomm4evnrxgmnoqxc2    52927037220737                            0             5
# 2  [BlazeStake, Jito, Marinade]       True  https://prod-validators.nyc3.digitaloceanspaces.com/s4pd0t8eyorvzfrm5js38weqn1me  2024522225108597                            0             0
# 3                  [BlazeStake]       True  https://prod-validators.nyc3.digitaloceanspaces.com/3gufbxp1khfyadpw66cogyp5rlpm    24680203689888                            0             0
# 4                            []       True  https://prod-validators.nyc3.digitaloceanspaces.com/hhvhwtpu36rm1d60cwdyvb3ftyce    95365033706503                            0             5
#
#    data_center_concentration_score  delinquent  published_information_score  root_distance_score  security_report_score  skipped_slot_score  skipped_after_score software_version  \
# 0                                0       False                            2                    2                      1                   2                    0           2.1.21
# 1                                0       False                            2                    2                      1                   2                    0           2.1.21
# 2                                0       False                            2                    2                      1                   2                    0           2.1.21
# 3                                0       False                            2                    2                      1                   2                    2           2.1.21
# 4                                0       False                            2                    2                      1                   2                    2           2.1.21
#
#    software_version_score  stake_concentration_score  consensus_mods_score  vote_latency_score  total_score  vote_distance_score              ip              data_center_key  \
# 0                       2                          0                     0          2.00000000           13                    2       50.7.5.42              30058-IE-Dublin
# 1                       2                          0                     0          2.00000000           13                    2  185.191.117.17  213896-DE-Frankfurt am Main
# 2                       2                          0                     0          2.00000000           13                    2  149.255.37.142           29802-NL-Amsterdam
# 3                       2                          0                     0          2.00000000           13                    2    80.76.51.122              48014-AL-Tirana
# 4                       2                          0                     0          2.00000000           13                    2   103.106.58.23       396356-AR-Buenos Aires
#
#    autonomous_system_number latitude longitude data_center_host                                  vote_account   epoch_credits        epoch  \
# 0            30058.00000000  53.3382   -6.2591             None  FahWJg2PkphJaMUUCzdYhXkD5NngUuuFRFD3YCE3BSwb 149144.00000000 787.00000000
# 1           213896.00000000  50.1169    8.6837             None  EnRcbgr5r7EUS2P35szncy6TW6eWA9UQiU3yQRCDbh2P 149146.00000000 787.00000000
# 2            29802.00000000  52.3891    4.6563             None  HxRrsnbc6K8CdEo3LCTrSUkFaDDxv9BdJsTDzBKnUVWH 149311.00000000 787.00000000
# 3            48014.00000000  41.3253   19.8184             None  91ciyr81FJnZaoWcDT4PHwwdzgNp21cgH354JbCuxnwR 149306.00000000 787.00000000
# 4           396356.00000000    -36.0  -59.9964             None   xLabsqDpN9WHXEXSJXk1yhqh5H8BgcqiBP1CR6Mkjcb 149145.00000000 787.00000000
#
#                                                                                                  url  skipped_slots skipped_slot_percent  ping_time                        timestamp  \
# 0  https://www.validators.app/api/v1/validators/mainnet/4VrjyXQT61WFSjuG3ehgqZUK1jqvYqB46veQbXLotq3n            NaN                  NaN        NaN 2025-05-14 16:11:29.984106+00:00
# 1  https://www.validators.app/api/v1/validators/mainnet/DP9iBgK9c7tJYb83KhxQMFNc1LXYu7nE7EhWpEzQnjmg     0.00000000                  0.0        NaN 2025-05-14 16:11:29.984106+00:00
# 2  https://www.validators.app/api/v1/validators/mainnet/7y5VhV4fkz6r4zUmH2UiwPjLwXzPL1PcV28or5NWkWRL     0.00000000                  0.0        NaN 2025-05-14 16:11:29.984106+00:00
# 3  https://www.validators.app/api/v1/validators/mainnet/AAHSdsnRREfdQNzDGRxai8CLXh9EPCoRdwULPqBYd9fb     0.00000000                  0.0        NaN 2025-05-14 16:11:29.984106+00:00
# 4   https://www.validators.app/api/v1/validators/mainnet/xLabscif2DLnYg39rQThqi7A9E45L9qiysRZhmZ1ARE            NaN                  NaN        NaN 2025-05-14 16:11:29.984106+00:00
#
#                                      nodePubkey  commission_y            activatedStake           lastVote           rootSlot epochVoteAccount            credits   previous_credits  credits_earned  \
# 0  4VrjyXQT61WFSjuG3ehgqZUK1jqvYqB46veQbXLotq3n    0.00000000  129778594625380.00000000 339993667.00000000 339993636.00000000             True 729760280.00000000 729606256.00000000 154024.00000000
# 1  DP9iBgK9c7tJYb83KhxQMFNc1LXYu7nE7EhWpEzQnjmg    5.00000000   52927037220737.00000000 339993667.00000000 339993636.00000000             True 613989695.00000000 613835669.00000000 154026.00000000
# 2  7y5VhV4fkz6r4zUmH2UiwPjLwXzPL1PcV28or5NWkWRL    0.00000000 2024522225108597.00000000 339993667.00000000 339993636.00000000             True 763710680.00000000 763556489.00000000 154191.00000000
# 3  AAHSdsnRREfdQNzDGRxai8CLXh9EPCoRdwULPqBYd9fb    0.00000000   24680203689888.00000000 339993667.00000000 339993636.00000000             True 734183799.00000000 734029613.00000000 154186.00000000
# 4   xLabscif2DLnYg39rQThqi7A9E45L9qiysRZhmZ1ARE    5.00000000   95365033706503.00000000 339993667.00000000 339993636.00000000             True 579537629.00000000 579383604.00000000 154025.00000000
#
#                                      votePubkey  active_stake_SOL
# 0  FahWJg2PkphJaMUUCzdYhXkD5NngUuuFRFD3YCE3BSwb   129778.59462538
# 1  EnRcbgr5r7EUS2P35szncy6TW6eWA9UQiU3yQRCDbh2P    52927.03722074
# 2  HxRrsnbc6K8CdEo3LCTrSUkFaDDxv9BdJsTDzBKnUVWH  2024522.22510860
# 3  91ciyr81FJnZaoWcDT4PHwwdzgNp21cgH354JbCuxnwR    24680.20368989
# 4   xLabsqDpN9WHXEXSJXk1yhqh5H8BgcqiBP1CR6Mkjcb    95365.03370650

# %%
# ['avatar_url','name', active_stake', 'activatedStake', 'lastVote', 'rootSlot', 'delinquent', 'commission', 'epoch_credits', 'skipped_slot_percent', 'jito_commission', 'jito','details','data_center_key','latitude',	'longitude' ]

# %%
current_validator_performance = df_merge[
    ['avatar_url', 'name', 'active_stake_SOL', 'delinquent', 'commission_y', 
     'epoch_credits', 'skipped_slot_percent', 'jito_commission', 'jito', 
     'details']
    ]

current_validator_performance.head()
# Out:
#                                                                                         avatar_url                                  name  active_stake_SOL  delinquent  commission_y   epoch_credits  \
# 0  https://s3.amazonaws.com/keybase_processed_uploads/c00270ec4b198ab0aa96b654ea7cd605_360_360.jpg                 Vault X | 0% fee +MEV   129778.59462538       False    0.00000000 149144.00000000
# 1                                                         https://pro.sec3.dev/sec3_logo_solid.png                                  Sec3    52927.03722074       False    5.00000000 149146.00000000
# 2                                                            https://www.staking.haus/hauslogo.png  Haus – Guaranteed Best APY & No Fees  2024522.22510860       False    0.00000000 149311.00000000
# 3  https://s3.amazonaws.com/keybase_processed_uploads/f0dba3e5b88045f95b11db2ebc38ab05_360_360.jpg                             StakeArmy    24680.20368989       False    0.00000000 149306.00000000
# 4                                                                 https://xlabs.xyz/xlabs-icon.png                                 xLabs    95365.03370650       False    5.00000000 149145.00000000
#
#   skipped_slot_percent  jito_commission  jito  \
# 0                  NaN       0.00000000  True
# 1                  0.0     800.00000000  True
# 2                  0.0       0.00000000  True
# 3                  0.0    1000.00000000  True
# 4                  NaN    1000.00000000  True
#
#                                                                                                                                                                                                                                                    details
# 0                                                                                                                                                                                                                               Safety, reliability, speed
# 1                                                                                                                                       Sec3 is a security and research firm providing bespoke audits and cutting edge security software to Web3 projects.
# 2  Haus is a Solana-focused validator with 0% fees. We guarantee the highest returns by matching the highest APY validator on the network (even if it’s not us), and we give large stakers an extra 10% native APY boost. Contact us at info@staking.haus.
# 3                                                                                                                                                                                                                                              High Uptime
# 4                                                                                                                                                                             Core infrastructure and open-source contributions for the internet of value.

# %%
latest_epoch = df_cleaned['epoch'].max()

df_cleaned = df_cleaned.dropna()
# Filter out the rows with the latest epoch where total_rewards and total_active_stake are NaN
df_cleaned = df_cleaned[~((df_cleaned['epoch'] == latest_epoch) & df_cleaned['total_rewards'].isna() & df_cleaned['total_active_stake'].isna())].reset_index(drop=True)



df_cleaned.head(n=5)
# Out:
#    epoch  starting_slot  slots_in_epoch  network                created_at            total_rewards          total_active_stake                        timestamp  \
# 0    786      339552000          432000  mainnet  2025-05-12T15:30:43.000Z 149109012834211.00000000 392945212855265664.00000000 2025-05-14 16:11:29.984106+00:00
# 1    786      339552000          432000  mainnet  2025-05-12T15:30:43.000Z 149109012834211.00000000 392945212855265664.00000000 2025-05-14 16:11:29.984106+00:00
# 2    786      339552000          432000  mainnet  2025-05-12T15:30:43.000Z 149109012834211.00000000 392945212855265664.00000000 2025-05-14 16:11:29.984106+00:00
# 3    786      339552000          432000  mainnet  2025-05-12T15:30:43.000Z 149109012834211.00000000 392945212855265664.00000000 2025-05-14 16:11:29.984106+00:00
# 4    786      339552000          432000  mainnet  2025-05-12T15:30:43.000Z 149109012834211.00000000 392945212855265664.00000000 2025-05-14 16:11:29.984106+00:00
#
#                                      nodePubkey  commission  activatedStake   lastVote   rootSlot  epochVoteAccount    credits  previous_credits  credits_earned  \
# 0  FYWeJ3uyJRHPUYj84ebhPAa7ZTeq9WU8LHQaKAgDcF74           0  24641650865315  339993667  339993636              True  621085381         614207076         6878305
# 1  FUyx2W6wDt7u363QgQRWQYuytE5uJWZLGJpuVh3RDiCa           0  22193129928221  339993667  339993636              True  779861814         772983643         6878171
# 2  FXfNZwnDQxNR3NVHzA3Xpctzey7AUmgz5YvWTHiUActw           0  16822136726179  339993666  339993635              True  546179957         539837184         6342773
# 3  FVZLnRhj9Gjf77CtDFvh7jNu8avAnduJW5m365HrDLfD           0  53614534334766  339993667  339993636              True  595772336         588908389         6863947
# 4  FZrSKKsKfZJovcQWRQFDXz8DbHKCSRZLZqbBAGd1dG57           0  29137638153817  339993667  339993636              True  734693927         727815637         6878290
#
#                                      votePubkey  activatedStake_SOL  activatedStake_USD                                  vote_account  total_reward_SOL  total_active_stake_SOL  \
# 0  G5dZZ3J95jER4v7N5LBg73ybxfg9RxFBpVc3LAY57UPu      24641.65086532    4363789.95173863  G5dZZ3J95jER4v7N5LBg73ybxfg9RxFBpVc3LAY57UPu   149109.01283421      392945212.85526568
# 1  AZUYzQX7nrbN1iE25YsSCSZAywZcyr1C1anMnwZtaqX9      22193.12992822    3930181.37898866  AZUYzQX7nrbN1iE25YsSCSZAywZcyr1C1anMnwZtaqX9   149109.01283421      392945212.85526568
# 2  EWRHPjhZmYj4oqgo4MyjuqoWzuPhCcRvTtdGDjuLWeMq      16822.13672618    2979032.19283904  EWRHPjhZmYj4oqgo4MyjuqoWzuPhCcRvTtdGDjuLWeMq   149109.01283421      392945212.85526568
# 3  EijMpL5u45wg1ZTJZa4i7DvUsn8um8s5woVJsNmvCpTP      53614.53433477    9494597.88534371  EijMpL5u45wg1ZTJZa4i7DvUsn8um8s5woVJsNmvCpTP   149109.01283421      392945212.85526568
# 4  8FPz3JG4E3HVXxGbPZVibarva4AGXSZWx3qKLUS5uFtN      29137.63815382    5159984.34065945  8FPz3JG4E3HVXxGbPZVibarva4AGXSZWx3qKLUS5uFtN   149109.01283421      392945212.85526568
#
#                                              name      keybase_id                   www_url  \
# 0  StakeRocket 🚀 0% Fee + Jito MEV 💰 Boosted APY!                   https://stakerocket.org
# 1                                 blockconsens.us  blockconsensus   https://blockconsens.us
# 2                                       Humbility                      https://humbility.io
# 3                        Han SOLana + Wookiee MEV                    https://hansolana.fun/
# 4                       Koinsortium ✨ 0% Fee +MEV     koinsortium  https://koinsortium.com/
#
#                                                                                                                                                                                                                                                                  details  \
# 0                                                                                                                                                                                             Trustworthy and high performance validator. Stake with us and take profit.
# 1
# 2
# 3  A long time ago, in a fast blockchain…\n\nHan SOLana and Wookiee MEV sign transactions so fast fees panic!\n\nDarkness approaches... A wicked validator with old hardware and hunger for sandwiches plans to raise gas fees!\n\nCan Han SOLana save the network, or w
# 4        Koinsоrtium is a team of expert validators. High-performance secure bare metal infrastructure and extremely reliable data center, high uptime and zero commission will allow you to get the maximum rewards for your stake. +Extra Jito MEV rewards! ❤️ 0% Fee
#
#                                                                                         avatar_url
# 0                                                             https://stakerocket.org/logo.png?v=1
# 1  https://s3.amazonaws.com/keybase_processed_uploads/1594481f0102efd41478816dd60e5a05_360_360.jpg
# 2                                 https://atlantis-email-signatures.s3.amazonaws.com/Logo(hum).png
# 3                          https://i.pinimg.com/736x/78/84/da/7884da2c7b3813094f03e09ca581e334.jpg
# 4  https://s3.amazonaws.com/keybase_processed_uploads/2ea9954d86f1ac918375d2355d888705_360_360.jpg

# %%
previous_validator_performanced = df_cleaned[
    ['avatar_url', 'name', 'activatedStake_SOL', 'commission', 
     'credits_earned', 'details']
    ]

previous_validator_performanced.head(n=5)
# Out:
#                                                                                         avatar_url                                            name  activatedStake_SOL  commission  credits_earned  \
# 0                                                             https://stakerocket.org/logo.png?v=1  StakeRocket 🚀 0% Fee + Jito MEV 💰 Boosted APY!      24641.65086532           0         6878305
# 1  https://s3.amazonaws.com/keybase_processed_uploads/1594481f0102efd41478816dd60e5a05_360_360.jpg                                 blockconsens.us      22193.12992822           0         6878171
# 2                                 https://atlantis-email-signatures.s3.amazonaws.com/Logo(hum).png                                       Humbility      16822.13672618           0         6342773
# 3                          https://i.pinimg.com/736x/78/84/da/7884da2c7b3813094f03e09ca581e334.jpg                        Han SOLana + Wookiee MEV      53614.53433477           0         6863947
# 4  https://s3.amazonaws.com/keybase_processed_uploads/2ea9954d86f1ac918375d2355d888705_360_360.jpg                       Koinsortium ✨ 0% Fee +MEV      29137.63815382           0         6878290
#
#                                                                                                                                                                                                                                                                  details
# 0                                                                                                                                                                                             Trustworthy and high performance validator. Stake with us and take profit.
# 1
# 2
# 3  A long time ago, in a fast blockchain…\n\nHan SOLana and Wookiee MEV sign transactions so fast fees panic!\n\nDarkness approaches... A wicked validator with old hardware and hunger for sandwiches plans to raise gas fees!\n\nCan Han SOLana save the network, or w
# 4        Koinsоrtium is a team of expert validators. High-performance secure bare metal infrastructure and extremely reliable data center, high uptime and zero commission will allow you to get the maximum rewards for your stake. +Extra Jito MEV rewards! ❤️ 0% Fee

# %%
df_cleaned["related_stake_percent"] = df_cleaned["activatedStake_SOL"]/df_cleaned["total_active_stake_SOL"]*100
df_cleaned["related_stake_percent"]
# Out:
# 0      0.00627101
# 1      0.00564789
# 2      0.00428104
# 3      0.01364428
# 4      0.00741519
#           ...
# 3304   0.00000000
# 3305   0.00000284
# 3306   0.00002743
# 3307   0.00328010
# 3308   0.00002993
# Name: related_stake_percent, Length: 3309, dtype: float64

# %% [markdown]
# # Top 10 Validators by Active Stake

# %%
df_merge

# Replace Python None and string 'None' with 'Unknown'
df_merge['name'] = df_merge['name'].replace([None, 'None'], 'Unknown')

df_merge['active_stake_SOL'] = pd.to_numeric(df_merge['active_stake_SOL'], errors='coerce')
#df_cleaned['related_stake_percent'] = pd.to_numeric(df_cleaned['related_stake_percent'], errors='coerce')

top_10_validators = df_merge[['name', 'active_stake_SOL']].sort_values(
    by='active_stake_SOL', ascending=False).head(10)

top_10_validators.reset_index(drop=True, inplace=True)

# Display the result
print(top_10_validators)
# Out:
#                 name  active_stake_SOL
# 0             Helius 13868641.51609672
# 1    binance staking 12559429.09187048
# 2             Galaxy  9433957.44257118
# 3        Coinbase 02  8882875.77089103
# 4  Ledger by Figment  8760199.33150853
# 5            Figment  7303080.76110702
# 6              Kiln1  6638421.20314387
# 7          Everstake  5907613.13522908
# 8      SOL Community  5863788.62856335
# 9            Unknown  5548951.53294512

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.barh(top_10_validators['name'], top_10_validators['active_stake_SOL'], color='mediumslateblue')
plt.xlabel('Active Stake (SOL)')
plt.title('Top 10 Validators by Active Stake')
plt.gca().invert_yaxis()  # Largest at the top
plt.tight_layout()
plt.show()

# %%
df_merge.columns.to_list()
# Out:
# ['network',
#  'account',
#  'name',
#  'keybase_id',
#  'www_url',
#  'details',
#  'avatar_url',
#  'created_at',
#  'updated_at',
#  'admin_warning',
#  'jito',
#  'jito_commission',
#  'stake_pools_list',
#  'is_active',
#  'avatar_file_url',
#  'active_stake',
#  'authorized_withdrawer_score',
#  'commission_x',
#  'data_center_concentration_score',
#  'delinquent',
#  'published_information_score',
#  'root_distance_score',
#  'security_report_score',
#  'skipped_slot_score',
#  'skipped_after_score',
#  'software_version',
#  'software_version_score',
#  'stake_concentration_score',
#  'consensus_mods_score',
#  'vote_latency_score',
#  'total_score',
#  'vote_distance_score',
#  'ip',
#  'data_center_key',
#  'autonomous_system_number',
#  'latitude',
#  'longitude',
#  'data_center_host',
#  'vote_account',
#  'epoch_credits',
#  'epoch',
#  'url',
#  'skipped_slots',
#  'skipped_slot_percent',
#  'ping_time',
#  'timestamp',
#  'nodePubkey',
#  'commission_y',
#  'activatedStake',
#  'lastVote',
#  'rootSlot',
#  'epochVoteAccount',
#  'credits',
#  'previous_credits',
#  'credits_earned',
#  'votePubkey',
#  'active_stake_SOL']

# %%
import matplotlib.pyplot as plt

# Select the relevant columns for geographical visualization
top_10_validators_geo = df_merge[['name', 'latitude', 'longitude']].iloc[top_10_validators.index]

# Plotting the geographical distribution (scatter plot)
plt.figure(figsize=(10, 6))
plt.scatter(top_10_validators_geo['longitude'], top_10_validators_geo['latitude'], color='blue', marker='o')

# Adding labels and title
for i, row in top_10_validators_geo.iterrows():
    plt.text(row['longitude'], row['latitude'], row['name'], fontsize=9, ha='right')

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Geographical Distribution of Top 10 Validators')

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9f/dspzp56j3pjcftph22hs9gw40000gn/T/ipykernel_62045/2309503528.py:19: UserWarning: Glyph 9989 (\N{WHITE HEAVY CHECK MARK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/olaoluwatunmise/miniconda3/envs/solana-predict/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 9989 (\N{WHITE HEAVY CHECK MARK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Staking Reward per epoch

# %%
df_epochs = joblib.load('df_epochs.joblib')

# %%
df_epochs = df_epochs.copy()

df_epochs['total_reward_SOL'] = df_epochs['total_rewards'] / 1e9
df_epochs['total_active_stake_SOL'] = df_epochs['total_active_stake'] / 1e9

# Convert to object type to allow string + float
df_epochs['total_reward_SOL'] = df_epochs['total_reward_SOL'].astype('object')
df_epochs['total_active_stake_SOL'] = df_epochs['total_active_stake_SOL'].astype('object')


df_epochs.loc[0, ['total_reward_SOL', 'total_active_stake_SOL']] = 'ongoing'
#df_epochs

staking_rewards = df_epochs[
    [ 'epoch', 'total_reward_SOL', 'total_active_stake_SOL'

    ]
]

staking_rewards
# Out:
#     epoch total_reward_SOL total_active_stake_SOL
# 0     787          ongoing                ongoing
# 1     786  149109.01283421     392945212.85526568
# 2     785  149125.95670135     390905360.20912164
# 3     784  148872.36731620     390601341.25554407
# 4     783  149356.86382339     391590155.18830347
# 5     782  149294.26984245     392310799.00643295
# 6     781  149600.37601859     391208956.63559538
# 7     780  149328.69851630     392498296.15884197
# 8     779  149221.32236707     389876708.02058911
# 9     778  149812.28436985     389896186.28602248
# 10    777  149912.53971820     389012068.85027254
# 11    776  150073.21416945     386851449.86945158
# 12    775  149701.47459307     389417669.74240601
# 13    774  150268.14346760     388835474.73470193
# 14    773  150318.62130607     388432150.68126887
# 15    772  150442.10367196     387325868.35411316
# 16    771  150521.98084456     385114681.64623022
# 17    770  150570.07666141     385199430.25477546
# 18    769  150140.89093105     383083844.12417054
# 19    768  150830.57292221     383589509.11026740
# 20    767  150895.05025193     384431426.98208392
# 21    766  151035.88782884     384502142.00397432
# 22    765  151158.73105243     384122910.55452269
# 23    764  151154.93672862     384962829.96158165
# 24    763  151268.35982831     384860360.61534399
# 25    762  151352.38774078     383804741.32266688
# 26    761  151427.86434513     381571194.96578544
# 27    760  151473.12510952     385044848.48208445
# 28    759  151116.26969698     384259373.68638873
# 29    758  151791.45244094     383245457.93894315
# 30    757  151922.06028458     383535820.56549913
# 31    756  152111.64363941     382023320.41690540
# 32    755  152036.54210738     377689756.61859322
# 33    754  152075.75169106     378508422.45612967
# 34    753  152236.84019631     380939862.40070641
# 35    752  152402.54989352     381036088.35852152
# 36    751  152463.81668237     379049853.60318065
# 37    750  152502.02155203     377684901.65309942
# 38    749  152163.50241206     372471319.13493907
# 39    748  152778.86148478     376274651.63541269
# 40    747  152751.43672051     380640126.90978414
# 41    746  152809.12674636     383879948.50440830
# 42    745  153015.32334012     384476729.59420496
# 43    744  153020.25779026     383079108.78873581
# 44    743  153167.47876169     389484210.53139639
# 45    742  153316.14929644     390534793.28734767
# 46    741  153417.15800436     389056717.94262004
# 47    740  153437.21874856     387587513.55154693
# 48    739  153096.49253244     385365168.00339258
# 49    738  153739.95877475     387999351.07883769

# %%
df_epochs['total_reward_SOL'] = pd.to_numeric(df_epochs['total_reward_SOL'], errors='coerce')
df_epochs['total_active_stake_SOL'] = pd.to_numeric(df_epochs['total_active_stake_SOL'], errors='coerce')
    
    # Drop epoch 786 (ongoing)
df = df_epochs[df_epochs['epoch'] != 786].copy()
    
    # Fill missing total_active_stake_SOL for epoch 773 with average of other epochs
avg_stake = df['total_active_stake_SOL'].mean()
df['total_active_stake_SOL'] = df['total_active_stake_SOL'].fillna(avg_stake)
    
    # Sort by epoch (descending)
df = df.sort_values('epoch', ascending=False)
    
df
# Out:
#     epoch  starting_slot  slots_in_epoch  network                created_at            total_rewards          total_active_stake  total_reward_SOL  total_active_stake_SOL
# 0     787      339984000          432000  mainnet  2025-05-14T15:07:05.000Z                      NaN                         NaN               NaN      385164018.78493220
# 2     785      339120000          432000  mainnet  2025-05-10T16:10:25.000Z 149125956701354.00000000 390905360209121664.00000000   149125.95670135      390905360.20912164
# 3     784      338688000          432000  mainnet  2025-05-08T16:51:08.000Z 148872367316200.00000000 390601341255544064.00000000   148872.36731620      390601341.25554407
# 4     783      338256000          432000  mainnet  2025-05-06T17:20:47.000Z 149356863823391.00000000 391590155188303488.00000000   149356.86382339      391590155.18830347
# 5     782      337824002          432000  mainnet  2025-05-04T18:04:09.000Z 149294269842450.00000000 392310799006432960.00000000   149294.26984245      392310799.00643295

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Total Rewards (SOL)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Secondary Y-axis: Active Stake
ax2 = ax1.twinx()
ax2.plot(df['epoch'], df['total_active_stake_SOL'], color='green', marker='x', label='Total Active Stake (SOL)')
ax2.set_ylabel('Total Active Stake (SOL)', color='green')
ax2.tick_params(axis='y', labelcolor='green')

# Title and layout
plt.title('Rewards and Active Stake Distribution by Epoch')
fig.tight_layout()
plt.show()

# %% [markdown]
# # Reward efficiency per epoch
# ### Analyzing validator economics
#
# Reward Rate =
# Total Active Stake / Total Reward
# ​

# %%
# Compute reward rate (rewards per unit staked)
df['reward_rate'] = df['total_reward_SOL'] / df['total_active_stake_SOL']

# Drop rows with NaN (optional, based on your data)
df = df.dropna(subset=['reward_rate'])

# Plot reward rate
plt.figure(figsize=(10, 5))
plt.plot(df['epoch'], df['reward_rate'], marker='o', color='purple')
plt.title('Reward Rate per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Reward Rate (SOL per staked SOL)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Inflation Rate Breakdown

# %%
df_inflation
# Out:
#    epoch  foundation      total  validator                        timestamp
# 0    787  0.00000000 0.04534296 0.04534296 2025-05-14 16:11:30.691305+00:00

# %% [markdown]
# # Network Overview

# %%
total_validator = df_expanded['vote_account'].unique().shape[0]
total_validator
# Out:
# 1324

# %%
df_epochs
# Out:
#     epoch  starting_slot  slots_in_epoch  network                created_at            total_rewards          total_active_stake  total_reward_SOL  total_active_stake_SOL
# 0     787      339984000          432000  mainnet  2025-05-14T15:07:05.000Z                      NaN                         NaN               NaN                     NaN
# 1     786      339552000          432000  mainnet  2025-05-12T15:30:43.000Z 149109012834211.00000000 392945212855265664.00000000   149109.01283421      392945212.85526568
# 2     785      339120000          432000  mainnet  2025-05-10T16:10:25.000Z 149125956701354.00000000 390905360209121664.00000000   149125.95670135      390905360.20912164
# 3     784      338688000          432000  mainnet  2025-05-08T16:51:08.000Z 148872367316200.00000000 390601341255544064.00000000   148872.36731620      390601341.25554407
# 4     783      338256000          432000  mainnet  2025-05-06T17:20:47.000Z 149356863823391.00000000 391590155188303488.00000000   149356.86382339      391590155.18830347
# 5     782      337824002          432000  mainnet  2025-05-04T18:04:09.000Z 149294269842450.00000000 392310799006432960.00000000   149294.26984245      392310799.00643295
# 6     781      337392000          432000  mainnet  2025-05-02T18:48:09.000Z 149600376018593.00000000 391208956635595392.00000000   149600.37601859      391208956.63559538
# 7     780      336960000          432000  mainnet  2025-04-30T19:23:26.000Z 149328698516297.00000000 392498296158841984.00000000   149328.69851630      392498296.15884197
# 8     779      336528001          432000  mainnet  2025-04-28T19:56:18.000Z 149221322367074.00000000 389876708020589120.00000000   149221.32236707      389876708.02058911
# 9     778      336096000          432000  mainnet  2025-04-26T20:24:27.000Z 149812284369850.00000000 389896186286022464.00000000   149812.28436985      389896186.28602248
# 10    777      335664000          432000  mainnet  2025-04-24T20:53:36.000Z 149912539718199.00000000 389012068850272512.00000000   149912.53971820      389012068.85027254
# 11    776      335232000          432000  mainnet  2025-04-22T21:15:51.000Z 150073214169453.00000000 386851449869451584.00000000   150073.21416945      386851449.86945158
# 12    775      334800000          432000  mainnet  2025-04-20T21:50:21.000Z 149701474593067.00000000 389417669742406016.00000000   149701.47459307      389417669.74240601
# 35    752      324864000          432000  mainnet  2025-03-06T01:52:42.000Z 152402549893523.00000000 381036088358521536.00000000   152402.54989352      381036088.35852152
# 36    751      324432000          432000  mainnet  2025-03-04T02:15:06.000Z 152463816682367.00000000 379049853603180672.00000000   152463.81668237      379049853.60318065
# 37    750      324000000          432000  mainnet  2025-03-02T02:44:20.000Z 152502021552031.00000000 377684901653099392.00000000   152502.02155203      377684901.65309942
# 38    749      323568000          432000  mainnet  2025-02-28T03:15:43.000Z 152163502412057.00000000 372471319134939072.00000000   152163.50241206      372471319.13493907
# 39    748      323136004          432000  mainnet  2025-02-26T03:45:53.000Z 152778861484778.00000000 376274651635412672.00000000   152778.86148478      376274651.63541269
# 40    747      322704000          432000  mainnet  2025-02-24T04:16:02.000Z 152751436720511.00000000 380640126909784128.00000000   152751.43672051      380640126.90978414
# 41    746      322272000          432000  mainnet  2025-02-22T04:45:22.000Z 152809126746356.00000000 383879948504408320.00000000   152809.12674636      383879948.50440830
# 42    745      321840000          432000  mainnet  2025-02-20T05:14:55.000Z 153015323340118.00000000 384476729594204992.00000000   153015.32334012      384476729.59420496
# 43    744      321408000          432000  mainnet  2025-02-18T05:42:44.000Z 153020257790256.00000000 383079108788735808.00000000   153020.25779026      383079108.78873581
# 44    743      320976000          432000  mainnet  2025-02-16T06:05:38.000Z 153167478761690.00000000 389484210531396416.00000000   153167.47876169      389484210.53139639
# 45    742      320544000          432000  mainnet  2025-02-14T06:33:12.000Z 153316149296444.00000000 390534793287347648.00000000   153316.14929644      390534793.28734767
# 46    741      320112000          432000  mainnet  2025-02-12T06:59:08.000Z 153417158004362.00000000 389056717942620032.00000000   153417.15800436      389056717.94262004
# 47    740      319680000          432000  mainnet  2025-02-10T07:27:43.000Z 153437218748561.00000000 387587513551546944.00000000   153437.21874856      387587513.55154693
# 48    739      319248000          432000  mainnet  2025-02-08T07:51:02.000Z 153096492532440.00000000 385365168003392576.00000000   153096.49253244      385365168.00339258
# 49    738      318816000          432000  mainnet  2025-02-06T08:17:21.000Z 153739958774747.00000000 387999351078837696.00000000   153739.95877475      387999351.07883769

# %%
# Filter out 'ongoing' rows
concluded_epochs = df_epochs[df_epochs['total_active_stake_SOL'] != 'ongoing']

# Sort by epoch in descending order and get the latest one
latest_concluded = concluded_epochs.sort_values(by='epoch', ascending=False).iloc[0]


latest_active_stake_SOL = latest_concluded['total_active_stake_SOL']
latest_epoch = latest_concluded['epoch']

print(f"Latest concluded epoch: {latest_epoch}")
print(f"Total active stake (SOL): {latest_active_stake_SOL}")
# Out:
# Latest concluded epoch: 787
# Total active stake (SOL): nan

# %%
tps = df_tps['tps']
tps
# Out:
# 0   4390.91666667
# Name: tps, dtype: float64

# %%
avg_fee_usd = df_fees['avg_fee_usd']
avg_fee_usd
# Out:
# 0   0.00088545
# Name: avg_fee_usd, dtype: float64

# %%
df_supply
# Out:
#      circulating_sol  nonCirculating_sol          total_sol
# 0 519564660.13983995   81234473.77101293 600799133.91085291

# %%
# Extract values
circulating = df_supply['circulating_sol'][0]
non_circulating = df_supply['nonCirculating_sol'][0]
