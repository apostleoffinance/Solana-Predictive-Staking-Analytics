# %%
from helius import NFTAPI, NameAPI, BalancesAPI, WebhooksAPI, TransactionsAPI
from dotenv import load_dotenv
from pathlib import Path
import requests
import pandas as pd
import numpy as np
import os
import time
import json
import joblib

# %%
pd.set_option('display.max_colwidth', None)  
pd.set_option('display.max_columns', None)   
pd.set_option('display.width', 200)    
pd.set_option('display.float_format', '{:.8f}'.format)

# %%
df_validators = joblib.load('df_validators.joblib')

df_expanded = joblib.load('df_expanded.joblib')

df_cleaned = joblib.load('df_cleaned.joblib')

df_tps = joblib.load('df_tps.joblib')

df_supply = joblib.load('df_supply.joblib')

df_fees = joblib.load('df_fees.joblib')

df_inflation = joblib.load('df_inflation.joblib')

# %%
df_validators #.head()
# Out:
#       network                                       account                     name keybase_id                      www_url  \
# 0     mainnet  2gDeeRa3mwPPtw1CMWPkEhRWo9v5izNBBfEXanr8uibX                     NuFi    nufi_vl                https://nu.fi
# 1     mainnet  8n4pc4sCJtBeLfJdGyJn6EcZuhtfTiepRa9ExdJFdmEN                Zeta Node                    https://zeta.markets
# 2     mainnet   juigBT2qetpYpf1iwgjaiWTjryKkY3uUTVAnRFKkqY6               ProStaking                  https://ProStaking.com
# 3     mainnet  6gnbmed7kzwQVQ7ghsjgEuCoYmGeWciV2qCwni6WS6HU  Capital Alliance 0% Fee                   https://capitall.app/
# 4     mainnet  3WDh9HgusCujDmXCVhophLrHvoKHQd1Sd4uFHz1Awo35           Absolute Guard              https://github.com/a-guard
# ...       ...                                           ...                      ...        ...                          ...
# 1260  mainnet  8iiLHGgCq66zEgcLJqQypJSKRMbXGYsNF7pwH3UdNskU                     None       None                         None
# 1261  mainnet  C3NxKEWdbR2XfHkCgbu2wCFeCCduJYkJ2pEomKx2wjRP          Gorilla Staking              https://gorillastaking.com
# 1262  mainnet  7QQGNm3ptwinipDCyaCF7jY5katgmFUu1ieP2f7nwLpE                     None       None                         None
# 1263  mainnet  5WgvknZoXna3Fm8qiAmi2D4sZg6u1iyCWNXWxhAc9p4B                      RNT             https://github.com/anza-xyz
# 1264  mainnet  4pc3MP7VM6J7HF7B4TF3NRhP6ayExjcitiAb8wB63Jvi                     None       None                         None
#
#                                                                                                                                                                                                                                                               details  \
# 0                                                                                                                                                                                                                                                    Try NuFi wallet!
# 1                                                                                                                                                                                   Zeta’s high-performing validator provides best-in-class security and reliability.
# 2                                                                                                                                                                                                   Pro Staking for Pro Stakers | formerly Juicy Stake | Follow @knox
# 3     Capital Alliance is a reliable, secure, and trusted validator committed to supporting Solana decentralization and growth. With ZERO FEES, enterprise-grade hardware, we ensure the BEST APY. Staking is open to all users and communities. Join our Discord for
# 4                                                                                                      Absolute Guard is a dedicated Solana validator providing robust network security and high performance, ensuring reliable and efficient transaction validation.
# ...                                                                                                                                                                                                                                                               ...
# 1260                                                                                                                                                                                                                                                             None
# 1261                                                                                                                                                                         Stake with us to earn Solana and extra blockchain rewards, including the Jito MEV bonus.
# 1262                                                                                                                                                                                                                                                             None
# 1263                                                                                                                                                                                                                                            Radiant Network Trail
# 1264                                                                                                                                                                                                                                                             None
#
# 4                               0           0                                0       False                            2                    2                      1                   2
# ...                           ...         ...                              ...         ...                          ...                  ...                    ...                 ...
# 1260                            0         100                                0        True                            0                    2                      0                   2
# 1261                            0         100                                0        True                            2                    2                      0                   2
# 1262                            0         100                                0       False                            0                    2                      0                   2
# 1263                            0           0                                0       False                            2                    2                      0                   2
# 1264                            0         100                                0        True                            0                    2                      0                   2
#
#       skipped_after_score software_version  software_version_score  stake_concentration_score  consensus_mods_score  vote_latency_score  total_score  vote_distance_score               ip  \
# 0                       2           2.1.21                       2                          0                     0          2.00000000           13                    2    109.74.144.98
# 1                       2           2.1.21                       2                          0                     0          2.00000000           13                    2   213.163.64.155
# 2                       2      0.411.20121                       2                          0                     0          2.00000000           13                    2      69.2.42.124
# 3                       2           2.1.21                       2                          0                     0          2.00000000           13                    2     46.21.153.94
# 4                       2           2.2.11                       2                          0                     0          2.00000000           13                    2   213.163.64.142
# ...                   ...              ...                     ...                        ...                   ...                 ...          ...                  ...              ...
# 1260                    2           2.1.21                       2                          0                     0          2.00000000            0                    2  216.158.233.134
# 1261                    2           2.1.21                       2                          0                     0          2.00000000            0                    2    151.106.9.123
# 1262                    1           2.1.20                       1                          0                     0          2.00000000            0                    2    5.199.172.176
# 1263                    2           2.1.21                       2                          0                     0          2.00000000            0                    2    62.197.45.222
# 1264                    2           2.1.21                       2                          0                     0          2.00000000            0                    2   161.129.64.146
#
#                data_center_key  autonomous_system_number latitude  longitude data_center_host                                  vote_account    epoch_credits        epoch  skipped_slots  \
# 0                29405-SK-Šaľa                     29405  48.1592    17.8834             None  3Xn3K5zeTzs4sURj1PCRaF6rvFg2hPgT49B4SiM998f7 1441686.00000000 786.00000000     0.00000000
# 1           49544-NL-Rotterdam                     49544  51.9281      4.422             None  FnAPJkzf19s87sm24Qhv6bHZMZvZ43gjNUBRgjwXpD4v 1441726.00000000 786.00000000     0.00000000
# 2         20355-US-Baton Rouge                     20355  30.4485     -91.13             None   juicQdAnksqZ5Yb8NQwCLjLWhykvXGktxnQCDvMe6Nx 1439474.00000000 786.00000000     0.00000000
# 3         29802-US-Los Angeles                     29802  34.0515  -118.2707             None   DTwEEF6VSrmTBYkDcj3BKAc52qhvP8CEQUEAMMT1cG3 1441686.00000000 786.00000000     0.00000000
# 4           49544-NL-Rotterdam                     49544  51.9281      4.422             None  9G19HT8xqceG7mKQVSrTRS3DGnGqDHErPyQEaEfyWEuW 1439330.00000000 786.00000000     0.00000000
# ...                        ...                       ...      ...        ...              ...                                           ...              ...          ...            ...
# 1260  19318-US-America/Chicago                     19318   37.751    -97.822             None  HdRcSKhqD4iG91qtsFpgATit1vZCcJQgbjnZoNdHmnC5  743274.00000000 786.00000000            NaN
# 1261       29066-FR-Strasbourg                     29066  48.5848     7.7419             None  GbRQmLLZFwc6Y2T6LWeKAj4jYRUA216kp2qrVrpT9avM  713024.00000000 786.00000000            NaN
# 1262          16125-LT-Vilnius                     16125  54.6912    25.2816             None  8BMMDVM8Tb88a2Hx1VSZ1TKmH1rMHbVU7xVafMk9JrEW 1439479.00000000 786.00000000     0.00000000
# 1263        58061-NL-Amsterdam                     58061  52.3759     4.8975             None   b3d74rXdGgdw9XeqRWgAnm7bsZgg9mf5J5hjZMqKxRD 1441742.00000000 786.00000000     0.00000000
# 1264        19318-NL-Amsterdam                     19318  52.3109     4.9453             None  DiSGejVwMNoXn3Digh4sPpNErMtu7UuKATRHdsBu9sgS  726761.00000000 786.00000000            NaN
#
#      skipped_slot_percent  ping_time                                                                                                url
# 0                     0.0        NaN  https://www.validators.app/api/v1/validators/mainnet/2gDeeRa3mwPPtw1CMWPkEhRWo9v5izNBBfEXanr8uibX
# 1                     0.0        NaN  https://www.validators.app/api/v1/validators/mainnet/8n4pc4sCJtBeLfJdGyJn6EcZuhtfTiepRa9ExdJFdmEN
# 2                     0.0        NaN   https://www.validators.app/api/v1/validators/mainnet/juigBT2qetpYpf1iwgjaiWTjryKkY3uUTVAnRFKkqY6
# 3                     0.0        NaN  https://www.validators.app/api/v1/validators/mainnet/6gnbmed7kzwQVQ7ghsjgEuCoYmGeWciV2qCwni6WS6HU
# 4                     0.0        NaN  https://www.validators.app/api/v1/validators/mainnet/3WDh9HgusCujDmXCVhophLrHvoKHQd1Sd4uFHz1Awo35
# ...                   ...        ...                                                                                                ...
# 1260                  NaN        NaN  https://www.validators.app/api/v1/validators/mainnet/8iiLHGgCq66zEgcLJqQypJSKRMbXGYsNF7pwH3UdNskU
# 1261                  NaN        NaN  https://www.validators.app/api/v1/validators/mainnet/C3NxKEWdbR2XfHkCgbu2wCFeCCduJYkJ2pEomKx2wjRP
# 1262                  0.0        NaN  https://www.validators.app/api/v1/validators/mainnet/7QQGNm3ptwinipDCyaCF7jY5katgmFUu1ieP2f7nwLpE
# 1263                  0.0        NaN  https://www.validators.app/api/v1/validators/mainnet/5WgvknZoXna3Fm8qiAmi2D4sZg6u1iyCWNXWxhAc9p4B
# 1264                  NaN        NaN  https://www.validators.app/api/v1/validators/mainnet/4pc3MP7VM6J7HF7B4TF3NRhP6ayExjcitiAb8wB63Jvi
#
# [1265 rows x 45 columns]

# %%
df_validators.columns.to_list()
# Out:
# ['network',
#  'account',
#  'name',
#  'keybase_id',
#  'www_url',
#  'details',
#  'avatar_url',
#  'created_at',
#  'updated_at',
#  'admin_warning',
#  'jito',
#  'jito_commission',
#  'stake_pools_list',
#  'is_active',
#  'avatar_file_url',
#  'active_stake',
#  'authorized_withdrawer_score',
#  'commission',
#  'data_center_concentration_score',
#  'delinquent',
#  'published_information_score',
#  'root_distance_score',
#  'security_report_score',
#  'skipped_slot_score',
#  'skipped_after_score',
#  'software_version',
#  'software_version_score',
#  'stake_concentration_score',
#  'consensus_mods_score',
#  'vote_latency_score',
#  'total_score',
#  'vote_distance_score',
#  'ip',
#  'data_center_key',
#  'autonomous_system_number',
#  'latitude',
#  'longitude',
#  'data_center_host',
#  'vote_account',
#  'epoch_credits',
#  'epoch',
#  'skipped_slots',
#  'skipped_slot_percent',
#  'ping_time',
#  'url']

# %%
df_expanded.head()
# Out:
#                             timestamp                                    nodePubkey  commission  activatedStake   lastVote   rootSlot  epochVoteAccount  epoch    credits  previous_credits  \
# 5852 2025-05-13 01:26:26.561946+00:00  138KHwTqKNWGLoo8fK5i8UxYtwoC5tC8o7M9rY1CDEjT           0  28931907684368  339642420  339642389              True    782  663485837         656598333
# 5853 2025-05-13 01:26:26.561946+00:00  138KHwTqKNWGLoo8fK5i8UxYtwoC5tC8o7M9rY1CDEjT           0  28931907684368  339642420  339642389              True    783  670375331         663485837
# 5854 2025-05-13 01:26:26.561946+00:00  138KHwTqKNWGLoo8fK5i8UxYtwoC5tC8o7M9rY1CDEjT           0  28931907684368  339642420  339642389              True    784  677274232         670375331
# 5855 2025-05-13 01:26:26.561946+00:00  138KHwTqKNWGLoo8fK5i8UxYtwoC5tC8o7M9rY1CDEjT           0  28931907684368  339642420  339642389              True    785  684174907         677274232
# 5856 2025-05-13 01:26:26.561946+00:00  138KHwTqKNWGLoo8fK5i8UxYtwoC5tC8o7M9rY1CDEjT           0  28931907684368  339642420  339642389              True    786  685616283         684174907
#
#       credits_earned                                    votePubkey
# 5852         6887504  ASfKFAKz6fH4eip1jdLGt5Ym954kU9KYnwq2Csn9ogSz
# 5853         6889494  ASfKFAKz6fH4eip1jdLGt5Ym954kU9KYnwq2Csn9ogSz
# 5854         6898901  ASfKFAKz6fH4eip1jdLGt5Ym954kU9KYnwq2Csn9ogSz
# 5855         6900675  ASfKFAKz6fH4eip1jdLGt5Ym954kU9KYnwq2Csn9ogSz
# 5856         1441376  ASfKFAKz6fH4eip1jdLGt5Ym954kU9KYnwq2Csn9ogSz

# %%
df_expanded['vote_account'] = df_expanded['votePubkey']

# %%
# df_expanded.columns.to_list()

# %%
df_merge = df_validators.merge(df_expanded, how = 'left', on = ['vote_account', 'epoch'] )

# %%
df_merge["active_stake_SOL"] = df_merge["active_stake"] / 1e9

# %%
df_merge.head()
# Out:
#    network                                       account                     name keybase_id                     www_url  \
# 0  mainnet  2gDeeRa3mwPPtw1CMWPkEhRWo9v5izNBBfEXanr8uibX                     NuFi    nufi_vl               https://nu.fi
# 1  mainnet  8n4pc4sCJtBeLfJdGyJn6EcZuhtfTiepRa9ExdJFdmEN                Zeta Node                   https://zeta.markets
# 2  mainnet   juigBT2qetpYpf1iwgjaiWTjryKkY3uUTVAnRFKkqY6               ProStaking                 https://ProStaking.com
# 3  mainnet  6gnbmed7kzwQVQ7ghsjgEuCoYmGeWciV2qCwni6WS6HU  Capital Alliance 0% Fee                  https://capitall.app/
# 4  mainnet  3WDh9HgusCujDmXCVhophLrHvoKHQd1Sd4uFHz1Awo35           Absolute Guard             https://github.com/a-guard
#
#                                                                                                                                                                                                                                                            details  \
# 0                                                                                                                                                                                                                                                 Try NuFi wallet!
# 1                                                                                                                                                                                Zeta’s high-performing validator provides best-in-class security and reliability.
# 2                                                                                                                                                                                                Pro Staking for Pro Stakers | formerly Juicy Stake | Follow @knox
# 3  Capital Alliance is a reliable, secure, and trusted validator committed to supporting Solana decentralization and growth. With ZERO FEES, enterprise-grade hardware, we ensure the BEST APY. Staking is open to all users and communities. Join our Discord for
# 4                                                                                                   Absolute Guard is a dedicated Solana validator providing robust network security and high performance, ensuring reliable and efficient transaction validation.
#
#                                                                                         avatar_url               created_at               updated_at admin_warning  jito  jito_commission  \
# 0  https://s3.amazonaws.com/keybase_processed_uploads/a547656e4d522f6c0eec7508ff61a605_360_360.jpg  2021-07-22 12:30:46 UTC  2025-04-24 03:40:06 UTC          None  True     800.00000000
# 1                                                             https://i.postimg.cc/HxCP6D0S/zm.png  2022-02-10 08:25:43 UTC  2025-04-19 03:40:05 UTC          None  True     800.00000000
# 2                                                                   https://tinyurl.com/prostaking  2022-06-20 18:30:06 UTC  2025-05-02 21:10:54 UTC          None  True     800.00000000
# 3                                          https://capitall.app/images/CapitalAlliance-sm-dark.jpg  2023-12-25 16:10:06 UTC  2025-05-01 03:40:05 UTC          None  True    1000.00000000
# 4                           https://raw.githubusercontent.com/a-guard/media-assets/master/logo.png  2024-06-05 09:39:09 UTC  2025-04-21 03:40:05 UTC          None  True       0.00000000
#
#                       stake_pools_list  is_active                                                                   avatar_file_url     active_stake  authorized_withdrawer_score  commission_x  \
# 0                  [Jito, Jpool, Aero]       True  https://prod-validators.nyc3.digitaloceanspaces.com/d297r2amrdfhvfxau8vxj17b9uyu  334760803209436                            0             0
# 1  [BlazeStake, Jito, Jpool, Marinade]       True  https://prod-validators.nyc3.digitaloceanspaces.com/3c3l28bezom96re6ni7h20z4v8zz   75304950447796                            0             0
# 2               [BlazeStake, Marinade]       True  https://prod-validators.nyc3.digitaloceanspaces.com/sakyp67c7qb04a63hje3a3v3rh37  751948733057295                            0             4
# 3                 [Edgevana, Marinade]       True  https://prod-validators.nyc3.digitaloceanspaces.com/szuka2uyd2fus3l1rmzy6jfurhzg   52466647039716                            0             0
# 4                         [BlazeStake]       True  https://prod-validators.nyc3.digitaloceanspaces.com/v1nx9az4qxvf5pq0sv7s6b19tr3j   47320488330777                            0             0
#
#    data_center_concentration_score  delinquent  published_information_score  root_distance_score  security_report_score  skipped_slot_score  skipped_after_score software_version  \
# 0                                0       False                            2                    2                      1                   2                    2           2.1.21
# 1                                0       False                            2                    2                      1                   2                    2           2.1.21
# 2                                0       False                            2                    2                      1                   2                    2      0.411.20121
# 3                                0       False                            2                    2                      1                   2                    2           2.1.21
# 4                                0       False                            2                    2                      1                   2                    2           2.2.11
#
#    software_version_score  stake_concentration_score  consensus_mods_score  vote_latency_score  total_score  vote_distance_score              ip       data_center_key  autonomous_system_number  \
# 0                       2                          0                     0          2.00000000           13                    2   109.74.144.98         29405-SK-Šaľa                     29405
# 1                       2                          0                     0          2.00000000           13                    2  213.163.64.155    49544-NL-Rotterdam                     49544
# 2                       2                          0                     0          2.00000000           13                    2     69.2.42.124  20355-US-Baton Rouge                     20355
# 3                       2                          0                     0          2.00000000           13                    2    46.21.153.94  29802-US-Los Angeles                     29802
# 4                       2                          0                     0          2.00000000           13                    2  213.163.64.142    49544-NL-Rotterdam                     49544
#
#   latitude  longitude data_center_host                                  vote_account    epoch_credits        epoch  skipped_slots skipped_slot_percent  ping_time  \
# 0  48.1592    17.8834             None  3Xn3K5zeTzs4sURj1PCRaF6rvFg2hPgT49B4SiM998f7 1441686.00000000 786.00000000     0.00000000                  0.0        NaN
# 1  51.9281      4.422             None  FnAPJkzf19s87sm24Qhv6bHZMZvZ43gjNUBRgjwXpD4v 1441726.00000000 786.00000000     0.00000000                  0.0        NaN
# 2  30.4485     -91.13             None   juicQdAnksqZ5Yb8NQwCLjLWhykvXGktxnQCDvMe6Nx 1439474.00000000 786.00000000     0.00000000                  0.0        NaN
# 3  34.0515  -118.2707             None   DTwEEF6VSrmTBYkDcj3BKAc52qhvP8CEQUEAMMT1cG3 1441686.00000000 786.00000000     0.00000000                  0.0        NaN
# 4  51.9281      4.422             None  9G19HT8xqceG7mKQVSrTRS3DGnGqDHErPyQEaEfyWEuW 1439330.00000000 786.00000000     0.00000000                  0.0        NaN
#
#                                                                                                  url                        timestamp                                    nodePubkey  commission_y  \
# 0  https://www.validators.app/api/v1/validators/mainnet/2gDeeRa3mwPPtw1CMWPkEhRWo9v5izNBBfEXanr8uibX 2025-05-13 01:26:26.561946+00:00  2gDeeRa3mwPPtw1CMWPkEhRWo9v5izNBBfEXanr8uibX    0.00000000
# 1  https://www.validators.app/api/v1/validators/mainnet/8n4pc4sCJtBeLfJdGyJn6EcZuhtfTiepRa9ExdJFdmEN 2025-05-13 01:26:26.561946+00:00  8n4pc4sCJtBeLfJdGyJn6EcZuhtfTiepRa9ExdJFdmEN    0.00000000
# 2   https://www.validators.app/api/v1/validators/mainnet/juigBT2qetpYpf1iwgjaiWTjryKkY3uUTVAnRFKkqY6 2025-05-13 01:26:26.561946+00:00   juigBT2qetpYpf1iwgjaiWTjryKkY3uUTVAnRFKkqY6    4.00000000
# 3  https://www.validators.app/api/v1/validators/mainnet/6gnbmed7kzwQVQ7ghsjgEuCoYmGeWciV2qCwni6WS6HU 2025-05-13 01:26:26.561946+00:00  6gnbmed7kzwQVQ7ghsjgEuCoYmGeWciV2qCwni6WS6HU    0.00000000
# 4  https://www.validators.app/api/v1/validators/mainnet/3WDh9HgusCujDmXCVhophLrHvoKHQd1Sd4uFHz1Awo35 2025-05-13 01:26:26.561946+00:00  3WDh9HgusCujDmXCVhophLrHvoKHQd1Sd4uFHz1Awo35    0.00000000
#
#             activatedStake           lastVote           rootSlot epochVoteAccount            credits   previous_credits   credits_earned                                    votePubkey  \
# 0 334760803209436.00000000 339642419.00000000 339642388.00000000             True 705259577.00000000 703818259.00000000 1441318.00000000  3Xn3K5zeTzs4sURj1PCRaF6rvFg2hPgT49B4SiM998f7
# 1  75304950447796.00000000 339642419.00000000 339642388.00000000             True 733453761.00000000 732012403.00000000 1441358.00000000  FnAPJkzf19s87sm24Qhv6bHZMZvZ43gjNUBRgjwXpD4v
# 2 751948733057295.00000000 339642419.00000000 339642388.00000000             True 718299931.00000000 716860809.00000000 1439122.00000000   juicQdAnksqZ5Yb8NQwCLjLWhykvXGktxnQCDvMe6Nx
# 3  52466647039716.00000000 339642419.00000000 339642388.00000000             True 631726892.00000000 630285558.00000000 1441334.00000000   DTwEEF6VSrmTBYkDcj3BKAc52qhvP8CEQUEAMMT1cG3
# 4  47320488330777.00000000 339642419.00000000 339642388.00000000             True 598956179.00000000 597517217.00000000 1438962.00000000  9G19HT8xqceG7mKQVSrTRS3DGnGqDHErPyQEaEfyWEuW
#
#    active_stake_SOL
# 0   334760.80320944
# 1    75304.95044780
# 2   751948.73305729
# 3    52466.64703972
# 4    47320.48833078

# %%
# ['avatar_url','name', active_stake', 'activatedStake', 'lastVote', 'rootSlot', 'delinquent', 'commission', 'epoch_credits', 'skipped_slot_percent', 'jito_commission', 'jito','details','data_center_key','latitude',	'longitude' ]

# %%
current_validator_performance = df_merge[
    ['avatar_url', 'name', 'active_stake_SOL', 'delinquent', 'commission_y', 
     'epoch_credits', 'skipped_slot_percent', 'jito_commission', 'jito', 
     'details']
    ]

current_validator_performance.head()
# Out:
#                                                                                         avatar_url                     name  active_stake_SOL  delinquent  commission_y    epoch_credits  \
# 0  https://s3.amazonaws.com/keybase_processed_uploads/a547656e4d522f6c0eec7508ff61a605_360_360.jpg                     NuFi   334760.80320944       False    0.00000000 1441686.00000000
# 1                                                             https://i.postimg.cc/HxCP6D0S/zm.png                Zeta Node    75304.95044780       False    0.00000000 1441726.00000000
# 2                                                                   https://tinyurl.com/prostaking               ProStaking   751948.73305729       False    4.00000000 1439474.00000000
# 3                                          https://capitall.app/images/CapitalAlliance-sm-dark.jpg  Capital Alliance 0% Fee    52466.64703972       False    0.00000000 1441686.00000000
# 4                           https://raw.githubusercontent.com/a-guard/media-assets/master/logo.png           Absolute Guard    47320.48833078       False    0.00000000 1439330.00000000
#
#   skipped_slot_percent  jito_commission  jito  \
# 0                  0.0     800.00000000  True
# 1                  0.0     800.00000000  True
# 2                  0.0     800.00000000  True
# 3                  0.0    1000.00000000  True
# 4                  0.0       0.00000000  True
#
#                                                                                                                                                                                                                                                            details
# 0                                                                                                                                                                                                                                                 Try NuFi wallet!
# 1                                                                                                                                                                                Zeta’s high-performing validator provides best-in-class security and reliability.
# 2                                                                                                                                                                                                Pro Staking for Pro Stakers | formerly Juicy Stake | Follow @knox
# 3  Capital Alliance is a reliable, secure, and trusted validator committed to supporting Solana decentralization and growth. With ZERO FEES, enterprise-grade hardware, we ensure the BEST APY. Staking is open to all users and communities. Join our Discord for
# 4                                                                                                   Absolute Guard is a dedicated Solana validator providing robust network security and high performance, ensuring reliable and efficient transaction validation.

# %%
latest_epoch = df_cleaned['epoch'].max()

df_cleaned = df_cleaned.dropna()
# Filter out the rows with the latest epoch where total_rewards and total_active_stake are NaN
df_cleaned = df_cleaned[~((df_cleaned['epoch'] == latest_epoch) & df_cleaned['total_rewards'].isna() & df_cleaned['total_active_stake'].isna())].reset_index(drop=True)



df_cleaned.head(n=5)
# Out:
#    epoch  starting_slot  slots_in_epoch  network                created_at            total_rewards          total_active_stake                        timestamp  \
# 0    785      339120000          432000  mainnet  2025-05-10T16:10:25.000Z 149125956701354.00000000 390905360209121664.00000000 2025-05-13 01:26:26.561946+00:00
# 1    785      339120000          432000  mainnet  2025-05-10T16:10:25.000Z 149125956701354.00000000 390905360209121664.00000000 2025-05-13 01:26:26.561946+00:00
# 2    785      339120000          432000  mainnet  2025-05-10T16:10:25.000Z 149125956701354.00000000 390905360209121664.00000000 2025-05-13 01:26:26.561946+00:00
# 3    785      339120000          432000  mainnet  2025-05-10T16:10:25.000Z 149125956701354.00000000 390905360209121664.00000000 2025-05-13 01:26:26.561946+00:00
# 4    785      339120000          432000  mainnet  2025-05-10T16:10:25.000Z 149125956701354.00000000 390905360209121664.00000000 2025-05-13 01:26:26.561946+00:00
#
#                                      nodePubkey  commission   activatedStake   lastVote   rootSlot  epochVoteAccount    credits  previous_credits  credits_earned  \
# 0  FLWc77X8dKh5RdJe5xMFxry8kvSVUbo9G4MQ8hCAg5ve           0   94355116478825  339642419  339642388              True  759218373         752317629         6900744
# 1  FUURpC3LjVnxr21PmEfHtxT7Mfe4CVJXxESBjQPvmqTZ           0  289213698736012  339642419  339642388              True  632550167         625649395         6900772
# 2  FU8F2V8yCFhseHDc1CJ5Sj1e5AbGNh3MnSe4REYX7a3P           0    5445170265861  339642419  339642388              True  663862661         656966327         6896334
# 3  FPPo2aGYYwDWK1Rmr4sXjiCaZzzMwGKi67ijAiVZKwb8           5   19012413531495  339642419  339642388              True  690386729         683485991         6900738
# 4  FNKgX9dYUhYQFRTM9bkeKoRpsyEtZGNMxbdQLDzfqB8a           8  832667342673228  339642419  339642388              True  131723774         124827770         6896004
#
#                                      votePubkey  activatedStake_SOL  activatedStake_USD                                  vote_account  total_reward_SOL  total_active_stake_SOL  \
# 0  EcZBjDPzSZLdsyKCBq26MZMYFfiinZsfcL3SwWMK1eNL      94355.11647883   16194168.64126074  EcZBjDPzSZLdsyKCBq26MZMYFfiinZsfcL3SwWMK1eNL   149125.95670135      390905360.20912164
# 1  2w4dcnbJDcGrAh4CFAYYpAaEJiUB2q1rFMGByBuB5Cqz     289213.69873601   49637747.11406174  2w4dcnbJDcGrAh4CFAYYpAaEJiUB2q1rFMGByBuB5Cqz   149125.95670135      390905360.20912164
# 2  A9YmK82uhCXieM9Cw9gN7W1F2KCxa8U1ArA6qxnyYcXQ       5445.17026586     934554.57272972  A9YmK82uhCXieM9Cw9gN7W1F2KCxa8U1ArA6qxnyYcXQ   149125.95670135      390905360.20912164
# 3  FKCcfoLt2pq7boiNqRGucVq5LE1K5Dt4HALCx2WbEQkv      19012.41353149    3263100.53441049  FKCcfoLt2pq7boiNqRGucVq5LE1K5Dt4HALCx2WbEQkv   149125.95670135      390905360.20912164
# 4  AaVsZUEnrHUZoXC2oVgTY3GF5GGhzCTBGrjpBtuUWy1H     832667.34267323  142910696.02300611  AaVsZUEnrHUZoXC2oVgTY3GF5GGhzCTBGrjpBtuUWy1H   149125.95670135      390905360.20912164
#
#                               name     keybase_id                                          www_url  \
# 0                           WALL·E                                             https://walle.co.za
# 1                         Vlaber01                 https://discordapp.com/users/880538802479857694
# 2  C-Key Validators | 0% fee + MEV                                          https://bit.ly/4d7hUv0
# 3                        NannyNode  nannyventures                           https://nanny.ventures
# 4                      Coinbase 04                                    https://coinbase.com/staking
#
#                                                                                                                                                   details  \
# 0                                                                                                  I dove into Solana's universe, mastering every aspect.
# 1                                                                                                                               Ukraine blockchain Solana
# 2                                                                                                                          Reliable staking. High result.
# 3                                                                                                                                      NannyVentures Team
# 4  Coinbase maintains world-class, enterprise-grade staking infrastructure across multiple networks with zero slashing events and a 99% uptime guarantee.
#
#                                                                                         avatar_url
# 0                                                              https://files.catbox.moe/6au3zf.png
# 1                                                    https://i.ibb.co/L0Hg3yK/ecosystem-solana.png
# 2                                                                 https://i.imgur.com/IbEWOmT.jpeg
# 3  https://s3.amazonaws.com/keybase_processed_uploads/a9876b838a0ebcfc74600f2c51bbb805_360_360.jpg
# 4                                 https://static-assets.coinbase.com/email/coinbase-logo-round.png

# %%
df_cleaned["related_stake_percent"] = df_cleaned["activatedStake_SOL"]/df_cleaned["total_active_stake_SOL"]*100
df_cleaned["related_stake_percent"]
# Out:
# 0      0.02413759
# 1      0.07398561
# 2      0.00139296
# 3      0.00486369
# 4      0.21300996
#           ...
# 3394   0.00241134
# 3395   0.00000054
# 3396   0.00075217
# 3397   0.00095105
# 3398   0.00002658
# Name: related_stake_percent, Length: 3399, dtype: float64

# %% [markdown]
# # Top 10 Validators by Active Stake

# %%
df_merge

# Replace Python None and string 'None' with 'Unknown'
df_merge['name'] = df_merge['name'].replace([None, 'None'], 'Unknown')

df_merge['active_stake_SOL'] = pd.to_numeric(df_merge['active_stake_SOL'], errors='coerce')
#df_cleaned['related_stake_percent'] = pd.to_numeric(df_cleaned['related_stake_percent'], errors='coerce')

top_10_validators = df_merge[['name', 'active_stake_SOL']].sort_values(
    by='active_stake_SOL', ascending=False).head(10)

top_10_validators.reset_index(drop=True, inplace=True)

# Display the result
print(top_10_validators)
# Out:
#                 name  active_stake_SOL
# 0             Helius 13837704.58902316
# 1    binance staking 12318202.08302838
# 2             Galaxy  9593093.10220637
# 3        Coinbase 02  8887827.71239061
# 4  Ledger by Figment  8754868.28274627
# 5            Figment  7566462.28773269
# 6              Kiln1  6632074.19772173
# 7          Everstake  5942626.50301785
# 8      SOL Community  5861700.62864363
# 9            Unknown  5534621.86033889

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.barh(top_10_validators['name'], top_10_validators['active_stake_SOL'], color='mediumslateblue')
plt.xlabel('Active Stake (SOL)')
plt.title('Top 10 Validators by Active Stake')
plt.gca().invert_yaxis()  # Largest at the top
plt.tight_layout()
plt.show()

# %%
df_merge.columns.to_list()
# Out:
# ['network',
#  'account',
#  'name',
#  'keybase_id',
#  'www_url',
#  'details',
#  'avatar_url',
#  'created_at',
#  'updated_at',
#  'admin_warning',
#  'jito',
#  'jito_commission',
#  'stake_pools_list',
#  'is_active',
#  'avatar_file_url',
#  'active_stake',
#  'authorized_withdrawer_score',
#  'commission_x',
#  'data_center_concentration_score',
#  'delinquent',
#  'published_information_score',
#  'root_distance_score',
#  'security_report_score',
#  'skipped_slot_score',
#  'skipped_after_score',
#  'software_version',
#  'software_version_score',
#  'stake_concentration_score',
#  'consensus_mods_score',
#  'vote_latency_score',
#  'total_score',
#  'vote_distance_score',
#  'ip',
#  'data_center_key',
#  'autonomous_system_number',
#  'latitude',
#  'longitude',
#  'data_center_host',
#  'vote_account',
#  'epoch_credits',
#  'epoch',
#  'skipped_slots',
#  'skipped_slot_percent',
#  'ping_time',
#  'url',
#  'timestamp',
#  'nodePubkey',
#  'commission_y',
#  'activatedStake',
#  'lastVote',
#  'rootSlot',
#  'epochVoteAccount',
#  'credits',
#  'previous_credits',
#  'credits_earned',
#  'votePubkey',
#  'active_stake_SOL']

# %%
import matplotlib.pyplot as plt

# Select the relevant columns for geographical visualization
top_10_validators_geo = df_merge[['name', 'latitude', 'longitude']].iloc[top_10_validators.index]

# Plotting the geographical distribution (scatter plot)
plt.figure(figsize=(10, 6))
plt.scatter(top_10_validators_geo['longitude'], top_10_validators_geo['latitude'], color='blue', marker='o')

# Adding labels and title
for i, row in top_10_validators_geo.iterrows():
    plt.text(row['longitude'], row['latitude'], row['name'], fontsize=9, ha='right')

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Geographical Distribution of Top 10 Validators')

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9f/dspzp56j3pjcftph22hs9gw40000gn/T/ipykernel_831/2309503528.py:19: UserWarning: Glyph 128640 (\N{ROCKET}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/olaoluwatunmise/miniconda3/envs/solana-predict/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128640 (\N{ROCKET}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
previous_validator_performanced = df_cleaned[
    ['avatar_url', 'name', 'activatedStake_SOL', 'commission', 
     'credits_earned', 'details']
    ]

previous_validator_performanced.head(n=5)
# Out:
#                                                                                         avatar_url                             name  activatedStake_SOL  commission  credits_earned  \
# 0                                                              https://files.catbox.moe/6au3zf.png                           WALL·E      94355.11647883           0         6900744
# 1                                                    https://i.ibb.co/L0Hg3yK/ecosystem-solana.png                         Vlaber01     289213.69873601           0         6900772
# 2                                                                 https://i.imgur.com/IbEWOmT.jpeg  C-Key Validators | 0% fee + MEV       5445.17026586           0         6896334
# 3  https://s3.amazonaws.com/keybase_processed_uploads/a9876b838a0ebcfc74600f2c51bbb805_360_360.jpg                        NannyNode      19012.41353149           5         6900738
# 4                                 https://static-assets.coinbase.com/email/coinbase-logo-round.png                      Coinbase 04     832667.34267323           8         6896004
#
#                                                                                                                                                   details
# 0                                                                                                  I dove into Solana's universe, mastering every aspect.
# 1                                                                                                                               Ukraine blockchain Solana
# 2                                                                                                                          Reliable staking. High result.
# 3                                                                                                                                      NannyVentures Team
# 4  Coinbase maintains world-class, enterprise-grade staking infrastructure across multiple networks with zero slashing events and a 99% uptime guarantee.

# %% [markdown]
# # Staking Reward per epoch

# %%
df_epochs = joblib.load('df_epochs.joblib')

# %%
df_epochs = df_epochs.copy()

df_epochs['total_reward_SOL'] = df_epochs['total_rewards'] / 1e9
df_epochs['total_active_stake_SOL'] = df_epochs['total_active_stake'] / 1e9

# Convert to object type to allow string + float
df_epochs['total_reward_SOL'] = df_epochs['total_reward_SOL'].astype('object')
df_epochs['total_active_stake_SOL'] = df_epochs['total_active_stake_SOL'].astype('object')


df_epochs.loc[0, ['total_reward_SOL', 'total_active_stake_SOL']] = 'ongoing'
#df_epochs

staking_rewards = df_epochs[
    [ 'epoch', 'total_reward_SOL', 'total_active_stake_SOL'

    ]
]

staking_rewards
# Out:
#     epoch total_reward_SOL total_active_stake_SOL
# 0     786          ongoing                ongoing
# 1     785  149125.95670135     390905360.20912164
# 2     784  148872.36731620     390601341.25554407
# 3     783  149356.86382339     391590155.18830347
# 4     782  149294.26984245     392310799.00643295
# 5     781  149600.37601859     391208956.63559538
# 6     780  149328.69851630     392498296.15884197
# 7     779  149221.32236707     389876708.02058911
# 8     778  149812.28436985     389896186.28602248
# 9     777  149912.53971820     389012068.85027254
# 10    776  150073.21416945     386851449.86945158
# 11    775  149701.47459307     389417669.74240601
# 12    774  150268.14346760     388835474.73470193
# 13    773  150318.62130607     388432150.68126887
# 14    772  150442.10367196     387325868.35411316
# 15    771  150521.98084456     385114681.64623022
# 16    770  150570.07666141     385199430.25477546
# 17    769  150140.89093105     383083844.12417054
# 18    768  150830.57292221     383589509.11026740
# 19    767  150895.05025193     384431426.98208392
# 20    766  151035.88782884     384502142.00397432
# 21    765  151158.73105243     384122910.55452269
# 22    764  151154.93672862     384962829.96158165
# 23    763  151268.35982831     384860360.61534399
# 24    762  151352.38774078     383804741.32266688
# 25    761  151427.86434513     381571194.96578544
# 26    760  151473.12510952     385044848.48208445
# 27    759  151116.26969698     384259373.68638873
# 28    758  151791.45244094     383245457.93894315
# 29    757  151922.06028458     383535820.56549913
# 30    756  152111.64363941     382023320.41690540
# 31    755  152036.54210738     377689756.61859322
# 32    754  152075.75169106     378508422.45612967
# 33    753  152236.84019631     380939862.40070641
# 34    752  152402.54989352     381036088.35852152
# 35    751  152463.81668237     379049853.60318065
# 36    750  152502.02155203     377684901.65309942
# 37    749  152163.50241206     372471319.13493907
# 38    748  152778.86148478     376274651.63541269
# 39    747  152751.43672051     380640126.90978414
# 40    746  152809.12674636     383879948.50440830
# 41    745  153015.32334012     384476729.59420496
# 42    744  153020.25779026     383079108.78873581
# 43    743  153167.47876169     389484210.53139639
# 44    742  153316.14929644     390534793.28734767
# 45    741  153417.15800436     389056717.94262004
# 46    740  153437.21874856     387587513.55154693
# 47    739  153096.49253244     385365168.00339258
# 48    738  153739.95877475     387999351.07883769
# 49    737  153724.08258723     386902708.08449954

# %%
import matplotlib.pyplot as plt

# Filter out 'ongoing' rows and convert types
staking_rewards_filtered = staking_rewards[
    staking_rewards['total_active_stake_SOL'] != 'ongoing'
].copy()

staking_rewards_filtered['total_reward_SOL'] = staking_rewards_filtered['total_reward_SOL'].astype(float)
staking_rewards_filtered['total_active_stake_SOL'] = staking_rewards_filtered['total_active_stake_SOL'].astype(float)

# Plot
fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(
    staking_rewards_filtered['epoch'], 
    staking_rewards_filtered['total_reward_SOL'], 
    color="#8A4AF3"
)

ax.set_title("Staking Reward Distribution per Epoch")
ax.set_xlabel("Epoch")
ax.set_ylabel("Total Reward (SOL)")
ax.grid(True, linestyle='--', alpha=0.5)

# Display in Streamlit
#st.pyplot(fig)

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar for rewards
ax1.bar(
    staking_rewards_filtered['epoch'], 
    staking_rewards_filtered['total_reward_SOL'], 
    color="#00C897", 
    label='Total Reward (SOL)'
)
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Reward (SOL)", color="#00C897")
ax1.tick_params(axis='y', labelcolor="#00C897")

# Line for active stake
ax2 = ax1.twinx()
ax2.plot(
    staking_rewards_filtered['epoch'], 
    staking_rewards_filtered['total_active_stake_SOL'], 
    color="#8A4AF3", 
    marker='o', 
    label='Total Active Stake (SOL)'
)
ax2.set_ylabel("Active Stake (SOL)", color="#8A4AF3")
ax2.tick_params(axis='y', labelcolor="#8A4AF3")

# Titles and layout
fig.suptitle("Staking Rewards and Active Stake per Epoch")
fig.tight_layout()

# Display in Streamlit
#st.pyplot(fig)

# %%
df_epochs['total_reward_SOL'] = pd.to_numeric(df_epochs['total_reward_SOL'], errors='coerce')
df_epochs['total_active_stake_SOL'] = pd.to_numeric(df_epochs['total_active_stake_SOL'], errors='coerce')
    
    # Drop epoch 786 (ongoing)
df = df_epochs[df_epochs['epoch'] != 786].copy()
    
    # Fill missing total_active_stake_SOL for epoch 773 with average of other epochs
avg_stake = df['total_active_stake_SOL'].mean()
df['total_active_stake_SOL'] = df['total_active_stake_SOL'].fillna(avg_stake)
    
    # Sort by epoch (descending)
df = df.sort_values('epoch', ascending=False)
    
df
# Out:
#     epoch  starting_slot  slots_in_epoch  network                created_at            total_rewards          total_active_stake  total_reward_SOL  total_active_stake_SOL
# 45    741      320112000          432000  mainnet  2025-02-12T06:59:08.000Z 153417158004362.00000000 389056717942620032.00000000   153417.15800436      389056717.94262004
# 46    740      319680000          432000  mainnet  2025-02-10T07:27:43.000Z 153437218748561.00000000 387587513551546944.00000000   153437.21874856      387587513.55154693
# 47    739      319248000          432000  mainnet  2025-02-08T07:51:02.000Z 153096492532440.00000000 385365168003392576.00000000   153096.49253244      385365168.00339258
# 48    738      318816000          432000  mainnet  2025-02-06T08:17:21.000Z 153739958774747.00000000 387999351078837696.00000000   153739.95877475      387999351.07883769
# 49    737      318384000          432000  mainnet  2025-02-04T08:29:54.000Z 153724082587233.00000000 386902708084499520.00000000   153724.08258723      386902708.08449954

# %%
#Plot with dual y-axes
fig, ax1 = plt.subplots(figsize=(10, 6))

# Primary Y-axis: Rewards
ax1.plot(df['epoch'], df['total_reward_SOL'], color='blue', marker='o', label='Total Rewards (SOL)')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Total Rewards (SOL)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Secondary Y-axis: Active Stake
ax2 = ax1.twinx()
ax2.plot(df['epoch'], df['total_active_stake_SOL'], color='green', marker='x', label='Total Active Stake (SOL)')
ax2.set_ylabel('Total Active Stake (SOL)', color='green')
ax2.tick_params(axis='y', labelcolor='green')

# Title and layout
plt.title('Rewards and Active Stake Distribution by Epoch')
fig.tight_layout()
plt.show()

# %% [markdown]
# # Reward efficiency per epoch
# ### Analyzing validator economics
#
# Reward Rate =
# Total Active Stake / Total Reward
# ​

# %%
# Compute reward rate (rewards per unit staked)
df['reward_rate'] = df['total_reward_SOL'] / df['total_active_stake_SOL']

# Drop rows with NaN (optional, based on your data)
df = df.dropna(subset=['reward_rate'])

# Plot reward rate
plt.figure(figsize=(10, 5))
plt.plot(df['epoch'], df['reward_rate'], marker='o', color='purple')
plt.title('Reward Rate per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Reward Rate (SOL per staked SOL)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Inflation Rate Breakdown

# %%
df_inflation
# Out:
#    epoch  foundation      total  validator                        timestamp
# 0    786  0.00000000 0.04538333 0.04538333 2025-05-13 01:26:27.260633+00:00

# %% [markdown]
# # Network Overview

# %%
total_validator = df_expanded['vote_account'].unique().shape[0]
total_validator
# Out:
# 1325

# %%
# Filter out 'ongoing' rows
concluded_epochs = df_epochs[df_epochs['total_active_stake_SOL'] != 'ongoing']

# Sort by epoch in descending order and get the latest one
latest_concluded = concluded_epochs.sort_values(by='epoch', ascending=False).iloc[0]


latest_active_stake_SOL = latest_concluded['total_active_stake_SOL']
latest_epoch = latest_concluded['epoch']

print(f"Latest concluded epoch: {latest_epoch}")
print(f"Total active stake (SOL): {latest_active_stake_SOL}")
# Out:
# Latest concluded epoch: 786
# Total active stake (SOL): nan

# %%
tps = df_tps['tps']
tps
# Out:
# 0   4214.68333333
# Name: tps, dtype: float64

# %%
avg_fee_usd = df_fees['avg_fee_usd']
avg_fee_usd
# Out:
# 0   0.00085815
# Name: avg_fee_usd, dtype: float64

# %%
df_supply
# Out:
#      circulating_sol  nonCirculating_sol          total_sol
# 0 519444081.87973523   81207422.19001375 600651504.06974900

# %%
# Extract values
circulating = df_supply['circulating_sol'][0]
non_circulating = df_supply['nonCirculating_sol'][0]
